# %%
import pandas as pd
import numpy as np

# %%
#read the files
file1 = pd.read_csv('file1.csv')
file2 = pd.read_csv('file2.csv')
file3 = pd.read_csv('file3.csv')

# %%
#show dataframe's shapes
print(file1.shape)
print(file2.shape)
file3.shape
# Out:
# (4008, 11)
# (996, 11)
# (7070, 11)

# %%
file1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
file2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
file3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
col1 = list(map(lambda el : el.lower(),file1))
file1.columns = col1
col2 = list(map(lambda el : el.lower(), file2))
file2.columns = col2
col3 = list(map(lambda el : el.lower(),file3))
file3.columns = col3

# %%
#standardize header names
file1 = file1.rename(columns={'st':'state'})
file2 = file2.rename(columns={'st':'state'})
file1
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
#remove file1 %
file1_custom = file1["customer lifetime value"].str.replace("%","")
file1['customer lifetime value'] = file1_custom
file1
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# ...

# %%
#remove file2 %
file2_custom = file2["customer lifetime value"].str.replace("%","")
file2['customer lifetime value'] = file2_custom
file2
# Out:
#     customer       state gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor               323912.47   16061
# 1    CW49887  California      F    Master               462680.11   79487
# 2    MY31220  California      F   College               899704.02   54230
# 3    UH35128      Oregon      F   College              2580706.30   71210
# 4    WH52799     Arizona      F   College               380812.21   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master               847141.75   63513
# 992  BS91566     Arizona      F   College               543121.91   58161
# 993  IL40123      Nevada      F   College               568964.41   83640
# 994  MY32149  California      F    Master               368672.38       0
# 995  SA91515  California      M  Bachelor               399258.39       0
#
#      monthly premium auto number of open complaints  total claim amount  \
# ...

# %%
#rearrange file2 columns
file2_rearranged = file2[['customer', 'state', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']]
file2_rearranged
# Out:
#     customer       state gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor               323912.47   16061
# 1    CW49887  California      F    Master               462680.11   79487
# 2    MY31220  California      F   College               899704.02   54230
# 3    UH35128      Oregon      F   College              2580706.30   71210
# 4    WH52799     Arizona      F   College               380812.21   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master               847141.75   63513
# 992  BS91566     Arizona      F   College               543121.91   58161
# 993  IL40123      Nevada      F   College               568964.41   83640
# 994  MY32149  California      F    Master               368672.38       0
# 995  SA91515  California      M  Bachelor               399258.39       0
#
#      monthly premium auto number of open complaints     policy type  \
# ...

# %%
#concatenate dataframes
dataset0 = pd.concat([file1,file2],axis=0)
dataset0.shape
# Out:
# (5004, 11)

# %%
#change dtype to numerical
new_column0 = pd.to_numeric(dataset0['customer lifetime value'], errors = 'coerce')
dataset0
dataset0['customer lifetime value'] = new_column0
dataset0.dtypes
dataset0 ['customer lifetime value'] = dataset0 ['customer lifetime value']/100
dataset0
# Out:
#     customer       state gender             education  \
# 0    RB50392  Washington    NaN                Master
# 1    QZ44356     Arizona      F              Bachelor
# 2    AI49188      Nevada      F              Bachelor
# 3    WW63253  California      M              Bachelor
# 4    GA49547  Washington      M  High School or Below
# ..       ...         ...    ...                   ...
# 991  HV85198     Arizona      M                Master
# 992  BS91566     Arizona      F               College
# 993  IL40123      Nevada      F               College
# 994  MY32149  California      F                Master
# 995  SA91515  California      M              Bachelor
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                  6979.5359      0.0                  94.0
# 2                 12887.4317  48767.0                 108.0
# 3                  7645.8618      0.0                 106.0
# ...

# %%
#rearrange file3 columns
file3_rearranged = file3[['customer', 'state', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']]
file3_rearranged.head()
# Out:
#   customer       state gender             education  customer lifetime value  \
# 0  SA25987  Washington      M  High School or Below              3479.137523
# 1  TB86706     Arizona      M                Master              2502.637401
# 2  ZL73902      Nevada      F              Bachelor              3265.156348
# 3  KX23516  California      F  High School or Below              4455.843406
# 4  FN77294  California      M  High School or Below              7704.958480
#
#    income  monthly premium auto  number of open complaints    policy type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    vehicle class  total claim amount
# ...

# %%
#concatenate dataframes
dataset = pd.concat([dataset0,file3],axis=0)
dataset.shape
# Out:
# (12074, 11)

# %%
#check for categorical and numerical columns
dataset.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer lifetime value      float64
# income                       float64
# monthly premium auto         float64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# dtype: object

# %%
dataset
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                 6979.535900      0.0                  94.0
# 2                12887.431700  48767.0                 108.0
# ...

# %%
# drop columns
dataset_drops = dataset.drop(['education','number of open complaints'], axis=1)
dataset_drops.head()
# Out:
#   customer       state gender  customer lifetime value   income  \
# 0  RB50392  Washington    NaN                      NaN      0.0
# 1  QZ44356     Arizona      F                6979.5359      0.0
# 2  AI49188      Nevada      F               12887.4317  48767.0
# 3  WW63253  California      M                7645.8618      0.0
# 4  GA49547  Washington      M                5363.0765  36357.0
#
#    monthly premium auto     policy type  vehicle class  total claim amount
# 0                1000.0   Personal Auto  Four-Door Car            2.704934
# 1                  94.0   Personal Auto  Four-Door Car         1131.464935
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 3                 106.0  Corporate Auto            SUV          529.881344
# 4                  68.0   Personal Auto  Four-Door Car           17.269323

# %%
#divide customer lifetime value / 100
dataset_drops ['customer lifetime value'] = dataset_drops ['customer lifetime value']/100
dataset_drops
# Out:
#      customer       state gender  customer lifetime value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F                69.795359      0.0
# 2     AI49188      Nevada      F               128.874317  48767.0
# 3     WW63253  California      M                76.458618      0.0
# 4     GA49547  Washington      M                53.630765  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M               234.059880  71941.0
# 7066  PK87824  California      F                30.965112  21604.0
# 7067  TD14365  California      M                81.638904      0.0
# 7068  UP19263  California      M                75.244424  21941.0
# 7069  Y167826  California      M                26.118369      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
#drop duplicates
dataset_drops = dataset_drops.drop_duplicates()
dataset_drops = dataset_drops.reset_index(drop=True)
dataset_drops
# Out:
#      customer       state gender  customer lifetime value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F                69.795359      0.0
# 2     AI49188      Nevada      F               128.874317  48767.0
# 3     WW63253  California      M                76.458618      0.0
# 4     GA49547  Washington      M                53.630765  36357.0
# ...       ...         ...    ...                      ...      ...
# 9130  LA72316  California      M               234.059880  71941.0
# 9131  PK87824  California      F                30.965112  21604.0
# 9132  TD14365  California      M                81.638904      0.0
# 9133  UP19263  California      M                75.244424  21941.0
# 9134  Y167826  California      M                26.118369      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
#income >0
filtered_data = dataset_drops[(dataset_drops['income']>0)]
filtered_data
# Out:
#      customer       state gender  customer lifetime value   income  \
# 2     AI49188      Nevada      F               128.874317  48767.0
# 4     GA49547  Washington      M                53.630765  36357.0
# 5     OC83172      Oregon      F                82.562978  62902.0
# 6     XZ87318      Oregon      F                53.808986  55350.0
# 8     DY87989      Oregon      M               241.275040  14072.0
# ...       ...         ...    ...                      ...      ...
# 9128  TF56202  California      M                50.321655  66367.0
# 9129  YM19146  California      F                41.003985  47761.0
# 9130  LA72316  California      M               234.059880  71941.0
# 9131  PK87824  California      F                30.965112  21604.0
# 9133  UP19263  California      M                75.244424  21941.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 2                    108.0   Personal Auto   Two-Door Car          566.472247
# ...
